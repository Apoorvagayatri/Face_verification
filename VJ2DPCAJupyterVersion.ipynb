# %%
# !pip3 install torchvision
# Out:
# Requirement already satisfied: torchvision in /Users/apoorvagayatrik/miniforge3/lib/python3.10/site-packages (0.18.1)
# Requirement already satisfied: numpy in /Users/apoorvagayatrik/miniforge3/lib/python3.10/site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: torch==2.3.1 in /Users/apoorvagayatrik/miniforge3/lib/python3.10/site-packages (from torchvision) (2.3.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/apoorvagayatrik/miniforge3/lib/python3.10/site-packages (from torchvision) (10.3.0)
# Requirement already satisfied: filelock in /Users/apoorvagayatrik/miniforge3/lib/python3.10/site-packages (from torch==2.3.1->torchvision) (3.15.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/apoorvagayatrik/miniforge3/lib/python3.10/site-packages (from torch==2.3.1->torchvision) (4.12.2)
# Requirement already satisfied: sympy in /Users/apoorvagayatrik/miniforge3/lib/python3.10/site-packages (from torch==2.3.1->torchvision) (1.12.1)
# Requirement already satisfied: networkx in /Users/apoorvagayatrik/miniforge3/lib/python3.10/site-packages (from torch==2.3.1->torchvision) (3.3)
# Requirement already satisfied: jinja2 in /Users/apoorvagayatrik/miniforge3/lib/python3.10/site-packages (from torch==2.3.1->torchvision) (3.1.4)
# Requirement already satisfied: fsspec in /Users/apoorvagayatrik/miniforge3/lib/python3.10/site-packages (from torch==2.3.1->torchvision) (2024.6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/apoorvagayatrik/miniforge3/lib/python3.10/site-packages (from jinja2->torch==2.3.1->torchvision) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /Users/apoorvagayatrik/miniforge3/lib/python3.10/site-packages (from sympy->torch==2.3.1->torchvision) (1.3.0)

# %%
import cv2
import os
import zipfile
import torch
import torchvision.transforms as transforms
from PIL import Image
import numpy as np

# %%
extract_dir='/Users/apoorvagayatrik/PerspectAIProj/og_dataset'

# %%
def detect_faces(image):

    face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    faces = face_cascade.detectMultiScale(gray_image, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

    return faces

# %%
datasets=['train_ds','val_ds','test_ds']

train_preprocessed=[]
val_preprocessed=[]
test_preprocessed=[]

# %%
# !pip3 install tqdm
# Out:
# Requirement already satisfied: tqdm in /Users/apoorvagayatrik/miniforge3/lib/python3.10/site-packages (4.66.4)

# %%
import os
import cv2
import numpy as np
from tqdm import tqdm

# Assuming detect_faces and apply_esrgan functions are already defined

datasets = ['train_ds', 'val_ds', 'test_ds']
extract_dir = '/Users/apoorvagayatrik/PerspectAIProj/og_dataset'  # Adjust this to your actual extract directory
output_dir = '/Users/apoorvagayatrik/PerspectAIProj/processed_images_noesrgan'  # Directory to save processed images

# Initialize lists for storing preprocessed images
train_preprocessed = []
val_preprocessed = []
test_preprocessed = []

train_labels = []
val_labels = []
test_labels = []

def load_images_and_labels(dataset):
    images = []
    labels = []
    dataset_path = os.path.join(extract_dir, dataset)
    people_folders = [f for f in os.listdir(dataset_path) if os.path.isdir(os.path.join(dataset_path, f))]

    progress_bar = tqdm(total=len(people_folders), desc=f'Processing {dataset}', unit='folder')

    for person_folder in people_folders:
        person_path = os.path.join(dataset_path, person_folder)
        image_files = [os.path.join(person_path, f) for f in os.listdir(person_path) if f.endswith('.jpg') or f.endswith('.png')]
        label = person_folder
        for image_path in image_files:
            image = cv2.imread(image_path, cv2.IMREAD_COLOR)
            faces = detect_faces(image)

            for (x, y, w, h) in faces:
                # Extract the face ROI
                face_roi = image[y:y+h, x:x+w]

                # Convert to grayscale
                gray_face = cv2.cvtColor(face_roi, cv2.COLOR_BGR2GRAY)

                # Resize the face to the target size
                target_size = (64, 64)
                resized_face = cv2.resize(gray_face, target_size)

                # Save processed image
                filename = os.path.basename(image_path)
                output_path = os.path.join(output_dir, dataset, person_folder, filename)
                os.makedirs(os.path.dirname(output_path), exist_ok=True)
                cv2.imwrite(output_path, resized_face)

                images.append(resized_face)
                labels.append(label)
        
        progress_bar.update(1)

    progress_bar.close()
    return images, labels

# Call the function to load and process images
train_preprocessed, train_labels = load_images_and_labels('train_ds')
val_preprocessed, val_labels = load_images_and_labels('val_ds')
test_preprocessed, test_labels = load_images_and_labels('test_ds')

print("Image loading completed!")
# Out:
# Processing train_ds:   0%|                         | 0/1755 [00:00<?, ?folder/s]
#
# Processing train_ds:   0%|                 | 1/1755 [00:00<04:09,  7.02folder/s]
#
# Processing train_ds:   0%|                 | 2/1755 [00:00<09:26,  3.09folder/s]
#
# Processing train_ds:   0%|                 | 3/1755 [00:00<07:53,  3.70folder/s]
#
# Processing train_ds:   0%|                 | 4/1755 [00:01<07:41,  3.80folder/s]
#
# Processing train_ds:   0%|                 | 6/1755 [00:01<07:05,  4.11folder/s]
#
# Processing train_ds:   0%|                 | 7/1755 [00:01<06:11,  4.70folder/s]
#
# Processing train_ds:   0%|                 | 8/1755 [00:02<08:36,  3.38folder/s]
#
# Processing train_ds:   1%|                 | 9/1755 [00:02<07:47,  3.73folder/s]
#
# Processing train_ds:   1%|                | 10/1755 [00:02<09:52,  2.94folder/s]
#
# Processing train_ds:   1%|                | 11/1755 [00:03<10:55,  2.66folder/s]
#
# Processing train_ds:   1%|                | 12/1755 [00:03<08:59,  3.23folder/s]
#
# Processing train_ds:   1%|                | 13/1755 [00:03<08:59,  3.23folder/s]
#
# Processing train_ds:   1%|▏               | 14/1755 [00:04<10:10,  2.85folder/s]
#
# Processing train_ds:   1%|▏               | 15/1755 [00:04<08:10,  3.55folder/s]
#
# Processing train_ds:   1%|▏               | 16/1755 [00:04<07:28,  3.88folder/s]
#
# Processing train_ds:   1%|▏               | 17/1755 [00:05<09:54,  2.92folder/s]
#
# Processing train_ds:   1%|▏               | 18/1755 [00:05<12:33,  2.31folder/s]
#
# Processing train_ds:   1%|▏               | 19/1755 [00:05<10:45,  2.69folder/s]
#
# Processing train_ds:   1%|▏               | 20/1755 [00:06<09:34,  3.02folder/s]
#
# Processing train_ds:   1%|▏               | 22/1755 [00:06<08:19,  3.47folder/s]
#
# Processing train_ds:   1%|▏               | 23/1755 [00:07<09:18,  3.10folder/s]
#
# Processing train_ds:   1%|▏               | 24/1755 [00:07<08:15,  3.49folder/s]
#
# Processing train_ds:   1%|▏               | 25/1755 [00:07<08:00,  3.60folder/s]
#
# Processing train_ds:   2%|▏               | 27/1755 [00:08<08:37,  3.34folder/s]
#
# Processing train_ds:   2%|▎               | 28/1755 [00:08<08:35,  3.35folder/s]
#
# Processing train_ds:   2%|▎               | 29/1755 [00:09<10:35,  2.72folder/s]
#
# Processing train_ds:   2%|▎               | 30/1755 [00:09<08:49,  3.26folder/s]
#
# Processing train_ds:   2%|▎               | 31/1755 [00:09<08:36,  3.34folder/s]
#
# Processing train_ds:   2%|▎               | 32/1755 [00:09<07:40,  3.74folder/s]
#
# Processing train_ds:   2%|▎               | 33/1755 [00:10<08:51,  3.24folder/s]
#
# Processing train_ds:   2%|▎               | 34/1755 [00:10<08:21,  3.43folder/s]
#
# Processing train_ds:   2%|▎               | 35/1755 [00:10<10:01,  2.86folder/s]
#
# Processing train_ds:   2%|▎               | 36/1755 [00:11<11:47,  2.43folder/s]
#
# Processing train_ds:   2%|▎               | 37/1755 [00:11<12:28,  2.30folder/s]
#
# Processing train_ds:   2%|▎               | 38/1755 [00:12<11:21,  2.52folder/s]
#
# Processing train_ds:   2%|▎               | 39/1755 [00:12<10:04,  2.84folder/s]
#
# Processing train_ds:   2%|▎               | 41/1755 [00:12<06:39,  4.29folder/s]
#
# Processing train_ds:   2%|▍               | 42/1755 [00:12<06:58,  4.10folder/s]
#
# Processing train_ds:   2%|▍               | 43/1755 [00:13<07:07,  4.00folder/s]
#
# Processing train_ds:   3%|▍               | 44/1755 [00:13<05:58,  4.77folder/s]
#
# Processing train_ds:   3%|▍               | 45/1755 [00:13<06:38,  4.29folder/s]
#
# Processing train_ds:   3%|▍               | 46/1755 [00:13<07:06,  4.01folder/s]
#
# Processing train_ds:   3%|▍               | 47/1755 [00:14<09:09,  3.11folder/s]
#
# Processing train_ds:   3%|▍               | 48/1755 [00:14<10:31,  2.70folder/s]
#
# Processing train_ds:   3%|▍               | 49/1755 [00:15<10:04,  2.82folder/s]
#
# Processing train_ds:   3%|▍               | 50/1755 [00:15<08:59,  3.16folder/s]
#
# Processing train_ds:   3%|▍               | 51/1755 [00:15<08:29,  3.34folder/s]
#
# Processing train_ds:   3%|▍               | 52/1755 [00:15<07:09,  3.97folder/s]
#
# Processing train_ds:   3%|▍               | 53/1755 [00:16<09:52,  2.87folder/s]
#
# Processing train_ds:   3%|▌               | 55/1755 [00:16<06:34,  4.31folder/s]
#
# Processing train_ds:   3%|▌               | 56/1755 [00:16<06:52,  4.12folder/s]
#
# Processing train_ds:   3%|▌               | 57/1755 [00:17<07:09,  3.95folder/s]
#
# Processing train_ds:   3%|▌               | 58/1755 [00:17<06:33,  4.32folder/s]
#
# Processing train_ds:   3%|▌               | 59/1755 [00:17<08:46,  3.22folder/s]
#
# Processing train_ds:   3%|▌               | 61/1755 [00:18<08:04,  3.50folder/s]
#
# Processing train_ds:   4%|▌               | 62/1755 [00:18<07:52,  3.58folder/s]
#
# Processing train_ds:   4%|▌               | 63/1755 [00:19<09:08,  3.09folder/s]
#
# Processing train_ds:   4%|▌               | 64/1755 [00:19<08:30,  3.31folder/s]
#
# Processing train_ds:   4%|▌               | 65/1755 [00:19<07:55,  3.56folder/s]
#
# Processing train_ds:   4%|▌               | 66/1755 [00:19<07:39,  3.67folder/s]
#
# Processing train_ds:   4%|▌               | 67/1755 [00:20<08:42,  3.23folder/s]
#
# Processing train_ds:   4%|▋               | 69/1755 [00:20<05:48,  4.84folder/s]
#
# Processing train_ds:   4%|▋               | 70/1755 [00:20<06:48,  4.13folder/s]
#
# Processing train_ds:   4%|▋               | 71/1755 [00:21<08:43,  3.22folder/s]
#
# Processing train_ds:   4%|▋               | 72/1755 [00:21<07:35,  3.70folder/s]
#
# Processing train_ds:   4%|▋               | 73/1755 [00:21<07:04,  3.96folder/s]
#
# Processing train_ds:   4%|▋               | 74/1755 [00:21<08:46,  3.19folder/s]
#
# Processing train_ds:   4%|▋               | 75/1755 [00:22<08:16,  3.39folder/s]
#
# Processing train_ds:   4%|▋               | 76/1755 [00:22<09:56,  2.81folder/s]
#
# Processing train_ds:   4%|▋               | 77/1755 [00:23<10:59,  2.55folder/s]
#
# Processing train_ds:   4%|▋               | 78/1755 [00:23<11:12,  2.49folder/s]
#
# Processing train_ds:   5%|▋               | 80/1755 [00:24<09:40,  2.89folder/s]
#
# Processing train_ds:   5%|▋               | 81/1755 [00:24<09:21,  2.98folder/s]
#
# Processing train_ds:   5%|▋               | 82/1755 [00:24<08:30,  3.28folder/s]
#
# Processing train_ds:   5%|▊               | 84/1755 [00:24<06:05,  4.57folder/s]
#
# Processing train_ds:   5%|▊               | 85/1755 [00:25<08:07,  3.42folder/s]
#
# Processing train_ds:   5%|▊               | 86/1755 [00:25<07:54,  3.52folder/s]
#
# Processing train_ds:   5%|▊               | 87/1755 [00:25<07:20,  3.78folder/s]
#
# Processing train_ds:   5%|▊               | 88/1755 [00:26<07:00,  3.96folder/s]
#
# Processing train_ds:   5%|▊               | 89/1755 [00:26<07:46,  3.57folder/s]
#
# Processing train_ds:   5%|▊               | 90/1755 [00:27<10:56,  2.54folder/s]
#
# Processing train_ds:   5%|▊               | 91/1755 [00:27<11:02,  2.51folder/s]
#
# Processing train_ds:   5%|▊               | 92/1755 [00:27<09:06,  3.04folder/s]
#
# Processing train_ds:   5%|▊               | 93/1755 [00:27<07:37,  3.63folder/s]
#
# Processing train_ds:   5%|▊               | 94/1755 [00:27<06:11,  4.47folder/s]
#
# Processing train_ds:   5%|▊               | 95/1755 [00:28<06:45,  4.10folder/s]
#
# Processing train_ds:   6%|▉               | 97/1755 [00:28<06:53,  4.01folder/s]
#
# Processing train_ds:   6%|▉               | 98/1755 [00:29<08:09,  3.39folder/s]
#
# Processing train_ds:   6%|▉               | 99/1755 [00:29<07:18,  3.78folder/s]
#
# Processing train_ds:   6%|▊              | 100/1755 [00:29<08:39,  3.19folder/s]
#
# Processing train_ds:   6%|▊              | 101/1755 [00:30<07:24,  3.72folder/s]
#
# Processing train_ds:   6%|▊              | 102/1755 [00:30<06:29,  4.25folder/s]
# Processing train_ds:   6%|▉              | 103/1755 [00:30<06:49,  4.03folder/s]
#
# Processing train_ds:   6%|▉              | 104/1755 [00:30<08:53,  3.09folder/s]
#
# Processing train_ds:   6%|▉              | 105/1755 [00:31<10:29,  2.62folder/s]
#
# Processing train_ds:   6%|▉              | 106/1755 [00:32<11:48,  2.33folder/s]
#
# Processing train_ds:   6%|▉              | 107/1755 [00:32<09:38,  2.85folder/s]
#
# Processing train_ds:   6%|▉              | 108/1755 [00:32<09:36,  2.86folder/s]
#
# Processing train_ds:   6%|▉              | 109/1755 [00:32<09:07,  3.01folder/s]
#
# Processing train_ds:   6%|▉              | 110/1755 [00:33<11:40,  2.35folder/s]
#
# Processing train_ds:   6%|▉              | 111/1755 [00:33<11:23,  2.40folder/s]
#
# Processing train_ds:   6%|▉              | 112/1755 [00:34<10:38,  2.57folder/s]
#
# Processing train_ds:   6%|▉              | 113/1755 [00:34<10:49,  2.53folder/s]
#
# Processing train_ds:   7%|▉              | 115/1755 [00:35<09:52,  2.77folder/s]
#
# Processing train_ds:   7%|▉              | 116/1755 [00:35<11:33,  2.36folder/s]
#
# Processing train_ds:   7%|█              | 117/1755 [00:35<09:35,  2.84folder/s]
#
# Processing train_ds:   7%|█              | 118/1755 [00:36<10:23,  2.63folder/s]
#
# Processing train_ds:   7%|█              | 119/1755 [00:36<10:19,  2.64folder/s]
#
# Processing train_ds:   7%|█              | 120/1755 [00:37<08:56,  3.05folder/s]
#
# Processing train_ds:   7%|█              | 121/1755 [00:37<08:43,  3.12folder/s]
#
# Processing train_ds:   7%|█              | 122/1755 [00:37<09:08,  2.98folder/s]
#
# Processing train_ds:   7%|█              | 123/1755 [00:38<09:14,  2.94folder/s]
#
# Processing train_ds:   7%|█              | 124/1755 [00:38<10:08,  2.68folder/s]
#
# Processing train_ds:   7%|█              | 125/1755 [00:38<08:02,  3.38folder/s]
#
# Processing train_ds:   7%|█              | 126/1755 [00:38<07:18,  3.71folder/s]
#
# Processing train_ds:   7%|█              | 127/1755 [00:39<09:27,  2.87folder/s]
#
# Processing train_ds:   7%|█              | 128/1755 [00:39<07:57,  3.40folder/s]
#
# Processing train_ds:   7%|█              | 129/1755 [00:39<08:32,  3.17folder/s]
#
# Processing train_ds:   7%|█              | 130/1755 [00:40<08:44,  3.10folder/s]
#
# Processing train_ds:   7%|█              | 131/1755 [00:40<11:34,  2.34folder/s]
#
# Processing train_ds:   8%|█▏             | 134/1755 [00:41<05:59,  4.51folder/s]
#
# Processing train_ds:   8%|█▏             | 136/1755 [00:41<04:27,  6.04folder/s]
#
# Processing train_ds:   8%|█▏             | 137/1755 [00:41<04:49,  5.59folder/s]
#
# Processing train_ds:   8%|█▏             | 139/1755 [00:41<03:50,  7.02folder/s]
#
# Processing train_ds:   8%|█▏             | 140/1755 [00:42<05:49,  4.63folder/s]
#
# Processing train_ds:   8%|█▏             | 142/1755 [00:42<04:33,  5.90folder/s]
#
# Processing train_ds:   8%|█▏             | 143/1755 [00:42<05:38,  4.76folder/s]
#
# Processing train_ds:   8%|█▏             | 144/1755 [00:43<07:13,  3.71folder/s]
#
# Processing train_ds:   8%|█▏             | 145/1755 [00:43<08:09,  3.29folder/s]
#
# Processing train_ds:   8%|█▎             | 147/1755 [00:43<06:23,  4.19folder/s]
#
# Processing train_ds:   8%|█▎             | 148/1755 [00:44<07:22,  3.63folder/s]
#
# Processing train_ds:   8%|█▎             | 149/1755 [00:44<07:51,  3.40folder/s]
#
# Processing train_ds:   9%|█▎             | 150/1755 [00:44<06:46,  3.94folder/s]
#
# Processing train_ds:   9%|█▎             | 151/1755 [00:44<06:00,  4.45folder/s]
#
# Processing train_ds:   9%|█▎             | 152/1755 [00:45<06:26,  4.15folder/s]
#
# Processing train_ds:   9%|█▎             | 153/1755 [00:45<07:27,  3.58folder/s]
#
# Processing train_ds:   9%|█▎             | 154/1755 [00:45<06:08,  4.34folder/s]
#
# Processing train_ds:   9%|█▎             | 155/1755 [00:45<07:03,  3.77folder/s]
#
# Processing train_ds:   9%|█▎             | 156/1755 [00:46<05:58,  4.46folder/s]
#
# Processing train_ds:   9%|█▎             | 157/1755 [00:46<07:50,  3.40folder/s]
#
# Processing train_ds:   9%|█▎             | 158/1755 [00:46<08:20,  3.19folder/s]
#
# Processing train_ds:   9%|█▎             | 159/1755 [00:47<07:16,  3.66folder/s]
#
# Processing train_ds:   9%|█▎             | 160/1755 [00:47<06:26,  4.12folder/s]
#
# Processing train_ds:   9%|█▍             | 161/1755 [00:47<08:23,  3.17folder/s]
#
# Processing train_ds:   9%|█▍             | 162/1755 [00:48<08:49,  3.01folder/s]
#
# Processing train_ds:   9%|█▍             | 163/1755 [00:48<07:42,  3.45folder/s]
#
# Processing train_ds:   9%|█▍             | 164/1755 [00:48<06:31,  4.07folder/s]
#
# Processing train_ds:   9%|█▍             | 165/1755 [00:48<05:55,  4.47folder/s]
#
# Processing train_ds:   9%|█▍             | 166/1755 [00:48<06:08,  4.31folder/s]
#
# Processing train_ds:  10%|█▍             | 167/1755 [00:49<05:57,  4.44folder/s]
#
# Processing train_ds:  10%|█▍             | 168/1755 [00:49<07:03,  3.75folder/s]
#
# Processing train_ds:  10%|█▍             | 169/1755 [00:49<08:41,  3.04folder/s]
#
# Processing train_ds:  10%|█▍             | 170/1755 [00:50<07:30,  3.52folder/s]
#
# Processing train_ds:  10%|█▍             | 171/1755 [00:50<07:20,  3.59folder/s]
#
# Processing train_ds:  10%|█▍             | 173/1755 [00:50<05:57,  4.42folder/s]
#
# Processing train_ds:  10%|█▍             | 174/1755 [00:50<05:09,  5.10folder/s]
#
# Processing train_ds:  10%|█▍             | 175/1755 [00:50<05:06,  5.15folder/s]
#
# Processing train_ds:  10%|█▌             | 176/1755 [00:51<04:43,  5.57folder/s]
#
# Processing train_ds:  10%|█▌             | 177/1755 [00:51<04:10,  6.31folder/s]
#
# Processing train_ds:  10%|█▌             | 178/1755 [00:51<05:42,  4.60folder/s]
#
# Processing train_ds:  10%|█▌             | 179/1755 [00:51<06:12,  4.23folder/s]
#
# Processing train_ds:  10%|█▌             | 180/1755 [00:52<09:19,  2.81folder/s]
#
# Processing train_ds:  10%|█▌             | 181/1755 [00:53<11:41,  2.25folder/s]
#
# Processing train_ds:  10%|█▌             | 183/1755 [00:53<07:18,  3.59folder/s]
#
# Processing train_ds:  10%|█▌             | 184/1755 [00:53<07:20,  3.57folder/s]
#
# Processing train_ds:  11%|█▌             | 186/1755 [00:54<06:43,  3.89folder/s]
#
# Processing train_ds:  11%|█▌             | 188/1755 [00:54<05:26,  4.79folder/s]
#
# Processing train_ds:  11%|█▌             | 189/1755 [00:54<06:36,  3.95folder/s]
#
# Processing train_ds:  11%|█▌             | 190/1755 [00:55<08:27,  3.08folder/s]
#
# Processing train_ds:  11%|█▋             | 191/1755 [00:55<07:31,  3.46folder/s]
#
# Processing train_ds:  11%|█▋             | 192/1755 [00:55<07:38,  3.41folder/s]
#
# Processing train_ds:  11%|█▋             | 194/1755 [00:55<05:09,  5.05folder/s]
#
# Processing train_ds:  11%|█▋             | 195/1755 [00:56<05:45,  4.52folder/s]
#
# Processing train_ds:  11%|█▋             | 196/1755 [00:56<06:35,  3.95folder/s]
#
# Processing train_ds:  11%|█▋             | 197/1755 [00:57<08:39,  3.00folder/s]
#
# Processing train_ds:  11%|█▋             | 200/1755 [00:57<05:51,  4.43folder/s]
#
# Processing train_ds:  11%|█▋             | 201/1755 [00:58<07:30,  3.45folder/s]
#
# Processing train_ds:  12%|█▋             | 202/1755 [00:58<07:19,  3.53folder/s]
#
# Processing train_ds:  12%|█▋             | 203/1755 [00:58<06:24,  4.03folder/s]
#
# Processing train_ds:  12%|█▋             | 204/1755 [00:58<08:11,  3.16folder/s]
#
# Processing train_ds:  12%|█▊             | 205/1755 [00:59<06:54,  3.74folder/s]
#
# Processing train_ds:  12%|█▊             | 207/1755 [00:59<04:53,  5.27folder/s]
#
# Processing train_ds:  12%|█▊             | 208/1755 [00:59<05:08,  5.01folder/s]
#
# Processing train_ds:  12%|█▊             | 210/1755 [00:59<04:11,  6.15folder/s]
#
# Processing train_ds:  12%|█▊             | 212/1755 [01:00<04:50,  5.31folder/s]
# Processing train_ds:  12%|█▊             | 214/1755 [01:00<04:02,  6.36folder/s]
#
# Processing train_ds:  12%|█▊             | 215/1755 [01:00<04:06,  6.25folder/s]
#
# Processing train_ds:  12%|█▊             | 216/1755 [01:00<04:16,  6.01folder/s]
#
# Processing train_ds:  12%|█▊             | 218/1755 [01:01<03:51,  6.65folder/s]
#
# Processing train_ds:  12%|█▊             | 219/1755 [01:01<04:20,  5.90folder/s]
#
# Processing train_ds:  13%|█▉             | 220/1755 [01:01<04:33,  5.62folder/s]
#
# Processing train_ds:  13%|█▉             | 221/1755 [01:01<04:23,  5.82folder/s]
#
# Processing train_ds:  13%|█▉             | 222/1755 [01:01<05:13,  4.88folder/s]
#
# Processing train_ds:  13%|█▉             | 223/1755 [01:02<08:06,  3.15folder/s]
#
# Processing train_ds:  13%|█▉             | 224/1755 [01:02<07:47,  3.28folder/s]
#
# Processing train_ds:  13%|█▉             | 225/1755 [01:03<08:24,  3.03folder/s]
#
# Processing train_ds:  13%|█▉             | 226/1755 [01:03<07:26,  3.42folder/s]
#
# Processing train_ds:  13%|█▉             | 227/1755 [01:03<06:51,  3.71folder/s]
#
# Processing train_ds:  13%|█▉             | 229/1755 [01:03<05:34,  4.57folder/s]
#
# Processing train_ds:  13%|█▉             | 230/1755 [01:04<06:02,  4.21folder/s]
#
# Processing train_ds:  13%|█▉             | 231/1755 [01:04<05:30,  4.61folder/s]
#
# Processing train_ds:  13%|█▉             | 232/1755 [01:04<05:34,  4.55folder/s]
#
# Processing train_ds:  13%|██             | 234/1755 [01:04<03:54,  6.49folder/s]
#
# Processing train_ds:  13%|██             | 236/1755 [01:04<03:09,  8.02folder/s]
#
# Processing train_ds:  14%|██             | 238/1755 [01:05<04:10,  6.06folder/s]
#
# Processing train_ds:  14%|██             | 239/1755 [01:05<04:17,  5.90folder/s]
#
# Processing train_ds:  14%|██             | 241/1755 [01:05<03:41,  6.84folder/s]
#
# Processing train_ds:  14%|██             | 242/1755 [01:05<03:27,  7.28folder/s]
#
# Processing train_ds:  18%|██▊            | 324/1755 [01:28<06:04,  3.93folder/s]
#
# Processing train_ds:  19%|██▊            | 326/1755 [01:28<06:04,  3.93folder/s]
# Processing train_ds:  19%|██▊            | 327/1755 [01:28<05:44,  4.14folder/s]
#
# Processing train_ds:  19%|██▊            | 328/1755 [01:29<05:48,  4.10folder/s]
#
# Processing train_ds:  19%|██▊            | 329/1755 [01:29<07:13,  3.29folder/s]
#
# Processing train_ds:  19%|██▊            | 330/1755 [01:29<07:40,  3.10folder/s]
#
# Processing train_ds:  19%|██▊            | 331/1755 [01:30<08:30,  2.79folder/s]
#
# Processing train_ds:  19%|██▊            | 332/1755 [01:30<08:17,  2.86folder/s]
#
# Processing train_ds:  19%|██▊            | 333/1755 [01:30<07:52,  3.01folder/s]
#
# Processing train_ds:  19%|██▊            | 334/1755 [01:31<08:16,  2.86folder/s]
#
# Processing train_ds:  19%|██▊            | 335/1755 [01:31<07:01,  3.37folder/s]
#
# Processing train_ds:  19%|██▊            | 336/1755 [01:31<08:18,  2.85folder/s]
#
# Processing train_ds:  19%|██▉            | 337/1755 [01:32<06:46,  3.49folder/s]
#
# Processing train_ds:  19%|██▉            | 338/1755 [01:32<05:51,  4.03folder/s]
#
# Processing train_ds:  19%|██▉            | 339/1755 [01:32<05:21,  4.40folder/s]
#
# Processing train_ds:  19%|██▉            | 341/1755 [01:32<04:05,  5.77folder/s]
#
# Processing train_ds:  19%|██▉            | 342/1755 [01:32<04:04,  5.78folder/s]
#
# Processing train_ds:  20%|██▉            | 343/1755 [01:33<07:07,  3.31folder/s]
#
# Processing train_ds:  20%|██▉            | 344/1755 [01:33<06:25,  3.66folder/s]
#
# Processing train_ds:  20%|██▉            | 345/1755 [01:33<05:55,  3.96folder/s]
#
# Processing train_ds:  20%|██▉            | 346/1755 [01:34<05:45,  4.08folder/s]
#
# Processing train_ds:  20%|██▉            | 348/1755 [01:34<04:39,  5.03folder/s]
#
# Processing train_ds:  20%|██▉            | 350/1755 [01:34<04:16,  5.47folder/s]
#
# Processing train_ds:  20%|███            | 351/1755 [01:35<04:53,  4.78folder/s]
#
# Processing train_ds:  20%|███            | 352/1755 [01:35<06:20,  3.69folder/s]
#
# Processing train_ds:  20%|███            | 353/1755 [01:35<05:48,  4.02folder/s]
#
# Processing train_ds:  20%|███            | 355/1755 [01:35<04:09,  5.60folder/s]
#
# Processing train_ds:  20%|███            | 356/1755 [01:36<04:20,  5.37folder/s]
#
# Processing train_ds:  20%|███            | 357/1755 [01:36<06:15,  3.72folder/s]
#
# Processing train_ds:  20%|███            | 358/1755 [01:36<05:56,  3.92folder/s]
#
# Processing train_ds:  20%|███            | 359/1755 [01:37<06:27,  3.60folder/s]
#
# Processing train_ds:  21%|███            | 361/1755 [01:37<06:06,  3.80folder/s]
#
# Processing train_ds:  21%|███            | 362/1755 [01:37<06:23,  3.63folder/s]
#
# Processing train_ds:  21%|███            | 363/1755 [01:38<06:02,  3.84folder/s]
#
# Processing train_ds:  21%|███            | 364/1755 [01:38<07:24,  3.13folder/s]
#
# Processing train_ds:  21%|███            | 365/1755 [01:39<08:55,  2.60folder/s]
#
# Processing train_ds:  21%|███▏           | 366/1755 [01:39<07:45,  2.98folder/s]
#
# Processing train_ds:  21%|███▏           | 368/1755 [01:39<07:10,  3.22folder/s]
#
# Processing train_ds:  21%|███▏           | 369/1755 [01:40<07:28,  3.09folder/s]
#
# Processing train_ds:  21%|███▏           | 370/1755 [01:40<06:39,  3.47folder/s]
#
# Processing train_ds:  21%|███▏           | 371/1755 [01:41<08:38,  2.67folder/s]
#
# Processing train_ds:  21%|███▏           | 372/1755 [01:41<08:58,  2.57folder/s]
#
# Processing train_ds:  21%|███▏           | 373/1755 [01:42<09:44,  2.36folder/s]
#
# Processing train_ds:  21%|███▏           | 374/1755 [01:42<08:28,  2.71folder/s]
#
# Processing train_ds:  21%|███▏           | 375/1755 [01:42<07:53,  2.92folder/s]
#
# Processing train_ds:  21%|███▏           | 376/1755 [01:42<06:58,  3.29folder/s]
#
# Processing train_ds:  22%|███▏           | 378/1755 [01:43<06:06,  3.76folder/s]
#
# Processing train_ds:  22%|███▏           | 379/1755 [01:43<06:16,  3.65folder/s]
#
# Processing train_ds:  22%|███▎           | 381/1755 [01:43<05:14,  4.36folder/s]
#
# Processing train_ds:  22%|███▎           | 382/1755 [01:44<05:23,  4.25folder/s]
#
# Processing train_ds:  22%|███▎           | 383/1755 [01:44<07:37,  3.00folder/s]
#
# Processing train_ds:  22%|███▎           | 384/1755 [01:45<08:31,  2.68folder/s]
#
# Processing train_ds:  22%|███▎           | 385/1755 [01:45<07:48,  2.93folder/s]
#
# Processing train_ds:  22%|███▎           | 386/1755 [01:45<08:39,  2.63folder/s]
#
# Processing train_ds:  22%|███▎           | 387/1755 [01:46<07:04,  3.22folder/s]
#
# Processing train_ds:  22%|███▎           | 389/1755 [01:46<06:11,  3.68folder/s]
#
# Processing train_ds:  22%|███▎           | 390/1755 [01:46<05:44,  3.97folder/s]
#
# Processing train_ds:  22%|███▎           | 391/1755 [01:46<05:06,  4.46folder/s]
#
# Processing train_ds:  22%|███▎           | 393/1755 [01:47<05:45,  3.94folder/s]
#
# Processing train_ds:  22%|███▎           | 394/1755 [01:48<07:15,  3.12folder/s]
#
# Processing train_ds:  23%|███▍           | 395/1755 [01:48<06:46,  3.35folder/s]
#
# Processing train_ds:  23%|███▍           | 396/1755 [01:48<06:12,  3.65folder/s]
#
# Processing train_ds:  23%|███▍           | 397/1755 [01:48<07:24,  3.05folder/s]
#
# Processing train_ds:  23%|███▍           | 399/1755 [01:49<06:43,  3.36folder/s]
#
# Processing train_ds:  23%|███▍           | 400/1755 [01:49<06:32,  3.45folder/s]
#
# Processing train_ds:  23%|███▍           | 401/1755 [01:50<06:55,  3.26folder/s]
#
# Processing train_ds:  23%|███▍           | 402/1755 [01:50<08:13,  2.74folder/s]
#
# Processing train_ds:  23%|███▍           | 403/1755 [01:50<07:39,  2.94folder/s]
#
# Processing train_ds:  23%|███▍           | 404/1755 [01:51<06:55,  3.25folder/s]
#
# Processing train_ds:  23%|███▍           | 405/1755 [01:51<05:43,  3.92folder/s]
#
# Processing train_ds:  23%|███▍           | 406/1755 [01:51<07:46,  2.89folder/s]
#
# Processing train_ds:  23%|███▍           | 407/1755 [01:51<06:46,  3.31folder/s]
#
# Processing train_ds:  23%|███▍           | 408/1755 [01:52<06:38,  3.38folder/s]
#
# Processing train_ds:  23%|███▍           | 409/1755 [01:52<08:15,  2.71folder/s]
#
# Processing train_ds:  23%|███▌           | 410/1755 [01:53<08:21,  2.68folder/s]
#
# Processing train_ds:  23%|███▌           | 411/1755 [01:53<08:23,  2.67folder/s]
#
# Processing train_ds:  23%|███▌           | 412/1755 [01:54<08:43,  2.57folder/s]
#
# Processing train_ds:  24%|███▌           | 413/1755 [01:54<07:16,  3.07folder/s]
#
# Processing train_ds:  24%|███▌           | 414/1755 [01:54<08:01,  2.79folder/s]
#
# Processing train_ds:  24%|███▌           | 416/1755 [01:55<06:44,  3.31folder/s]
#
# Processing train_ds:  24%|███▌           | 418/1755 [01:55<05:13,  4.26folder/s]
#
# Processing train_ds:  24%|███▌           | 419/1755 [01:55<06:14,  3.56folder/s]
#
# Processing train_ds:  24%|███▌           | 420/1755 [01:55<05:17,  4.21folder/s]
#
# Processing train_ds:  24%|███▌           | 421/1755 [01:56<05:18,  4.19folder/s]
#
# Processing train_ds:  24%|███▌           | 422/1755 [01:56<04:39,  4.77folder/s]
#
# Processing train_ds:  24%|███▌           | 423/1755 [01:56<04:22,  5.07folder/s]
#
# Processing train_ds:  24%|███▌           | 424/1755 [01:56<04:17,  5.16folder/s]
#
# Processing train_ds:  24%|███▋           | 426/1755 [01:57<05:13,  4.23folder/s]
#
# Processing train_ds:  24%|███▋           | 427/1755 [01:57<06:53,  3.21folder/s]
#
# Processing train_ds:  24%|███▋           | 428/1755 [01:57<05:57,  3.71folder/s]
#
# Processing train_ds:  24%|███▋           | 429/1755 [01:58<07:33,  2.93folder/s]
#
# Processing train_ds:  25%|███▋           | 430/1755 [01:58<07:04,  3.12folder/s]
#
# Processing train_ds:  25%|███▋           | 432/1755 [01:59<06:20,  3.48folder/s]
#
# Processing train_ds:  25%|███▋           | 433/1755 [01:59<06:05,  3.62folder/s]
#
# Processing train_ds:  25%|███▋           | 434/1755 [01:59<05:34,  3.95folder/s]
# Processing train_ds:  25%|███▋           | 435/1755 [01:59<04:51,  4.54folder/s]
#
# Processing train_ds:  25%|███▋           | 436/1755 [01:59<04:26,  4.96folder/s]
#
# Processing train_ds:  25%|███▋           | 437/1755 [02:00<03:52,  5.67folder/s]
#
# Processing train_ds:  25%|███▋           | 438/1755 [02:00<04:06,  5.35folder/s]
#
# Processing train_ds:  25%|███▊           | 439/1755 [02:00<05:03,  4.33folder/s]
#
# Processing train_ds:  25%|███▊           | 440/1755 [02:01<06:55,  3.17folder/s]
#
# Processing train_ds:  25%|███▊           | 441/1755 [02:01<08:17,  2.64folder/s]
#
# Processing train_ds:  25%|███▊           | 443/1755 [02:01<05:24,  4.04folder/s]
#
# Processing train_ds:  25%|███▊           | 444/1755 [02:01<04:40,  4.67folder/s]
#
# Processing train_ds:  25%|███▊           | 445/1755 [02:02<05:38,  3.87folder/s]
#
# Processing train_ds:  25%|███▊           | 446/1755 [02:02<05:14,  4.16folder/s]
#
# Processing train_ds:  26%|███▊           | 448/1755 [02:02<04:56,  4.41folder/s]
#
# Processing train_ds:  26%|███▊           | 449/1755 [02:03<05:14,  4.16folder/s]
#
# Processing train_ds:  26%|███▊           | 450/1755 [02:03<04:30,  4.82folder/s]
#
# Processing train_ds:  26%|███▊           | 451/1755 [02:03<06:25,  3.38folder/s]
#
# Processing train_ds:  26%|███▊           | 452/1755 [02:04<06:15,  3.47folder/s]
#
# Processing train_ds:  26%|███▊           | 453/1755 [02:04<06:45,  3.21folder/s]
#
# Processing train_ds:  26%|███▉           | 454/1755 [02:04<06:27,  3.36folder/s]
#
# Processing train_ds:  26%|███▉           | 455/1755 [02:05<07:20,  2.95folder/s]
#
# Processing train_ds:  26%|███▉           | 457/1755 [02:05<05:10,  4.18folder/s]
#
# Processing train_ds:  26%|███▉           | 458/1755 [02:05<04:41,  4.61folder/s]
#
# Processing train_ds:  26%|███▉           | 460/1755 [02:05<04:01,  5.37folder/s]
#
# Processing train_ds:  26%|███▉           | 461/1755 [02:06<04:44,  4.55folder/s]
#
# Processing train_ds:  26%|███▉           | 462/1755 [02:06<04:29,  4.80folder/s]
#
# Processing train_ds:  26%|███▉           | 463/1755 [02:06<05:35,  3.85folder/s]
#
# Processing train_ds:  26%|███▉           | 464/1755 [02:07<07:21,  2.92folder/s]
#
# Processing train_ds:  26%|███▉           | 465/1755 [02:07<07:24,  2.90folder/s]
#
# Processing train_ds:  27%|███▉           | 466/1755 [02:07<06:21,  3.38folder/s]
#
# Processing train_ds:  27%|███▉           | 467/1755 [02:08<06:29,  3.30folder/s]
#
# Processing train_ds:  27%|████           | 469/1755 [02:08<05:31,  3.87folder/s]
#
# Processing train_ds:  27%|████           | 470/1755 [02:08<05:19,  4.03folder/s]
#
# Processing train_ds:  27%|████           | 471/1755 [02:09<06:52,  3.12folder/s]
#
# Processing train_ds:  27%|████           | 472/1755 [02:09<07:33,  2.83folder/s]
#
# Processing train_ds:  27%|████           | 473/1755 [02:10<08:36,  2.48folder/s]
#
# Processing train_ds:  27%|████           | 475/1755 [02:10<05:33,  3.84folder/s]
#
# Processing train_ds:  27%|████           | 476/1755 [02:11<07:15,  2.94folder/s]
#
# Processing train_ds:  27%|████           | 477/1755 [02:11<07:58,  2.67folder/s]
#
# Processing train_ds:  27%|████           | 478/1755 [02:11<07:55,  2.69folder/s]
#
# Processing train_ds:  27%|████           | 479/1755 [02:12<07:15,  2.93folder/s]
#
# Processing train_ds:  27%|████           | 480/1755 [02:12<09:01,  2.35folder/s]
#
# Processing train_ds:  27%|████           | 481/1755 [02:13<10:48,  1.96folder/s]
# Processing train_ds:  32%|████▊          | 560/1755 [02:33<08:06,  2.46folder/s]
#
# Processing train_ds:  32%|████▊          | 561/1755 [02:33<08:37,  2.31folder/s]
#
# Processing train_ds:  32%|████▊          | 562/1755 [02:33<06:56,  2.87folder/s]
#
# Processing train_ds:  32%|████▊          | 563/1755 [02:33<05:29,  3.62folder/s]
#
# Processing train_ds:  32%|████▊          | 564/1755 [02:34<05:49,  3.41folder/s]
#
# Processing train_ds:  32%|████▊          | 565/1755 [02:34<05:33,  3.57folder/s]
#
# Processing train_ds:  32%|████▊          | 566/1755 [02:34<04:46,  4.14folder/s]
#
# Processing train_ds:  32%|████▊          | 567/1755 [02:34<04:26,  4.45folder/s]
#
# Processing train_ds:  32%|████▊          | 568/1755 [02:35<03:53,  5.08folder/s]
#
# Processing train_ds:  32%|████▊          | 570/1755 [02:35<02:48,  7.02folder/s]
#
# Processing train_ds:  33%|████▉          | 571/1755 [02:35<03:35,  5.50folder/s]
#
# Processing train_ds:  33%|████▉          | 572/1755 [02:35<03:31,  5.59folder/s]
#
# Processing train_ds:  33%|████▉          | 573/1755 [02:35<04:25,  4.46folder/s]
#
# Processing train_ds:  33%|████▉          | 576/1755 [02:36<02:32,  7.73folder/s]
#
# Processing train_ds:  33%|████▉          | 577/1755 [02:36<02:51,  6.86folder/s]
#
# Processing train_ds:  33%|████▉          | 579/1755 [02:37<04:29,  4.36folder/s]
#
# Processing train_ds:  33%|████▉          | 580/1755 [02:37<04:12,  4.65folder/s]
#
# Processing train_ds:  33%|████▉          | 581/1755 [02:37<05:01,  3.90folder/s]
#
# Processing train_ds:  33%|████▉          | 582/1755 [02:37<05:06,  3.83folder/s]
#
# Processing train_ds:  33%|████▉          | 583/1755 [02:38<04:17,  4.56folder/s]
#
# Processing train_ds:  33%|████▉          | 584/1755 [02:38<05:04,  3.84folder/s]
#
# Processing train_ds:  33%|█████          | 585/1755 [02:38<04:41,  4.16folder/s]
#
# Processing train_ds:  33%|█████          | 586/1755 [02:39<06:55,  2.82folder/s]
#
# Processing train_ds:  34%|█████          | 588/1755 [02:39<05:36,  3.47folder/s]
#
# Processing train_ds:  34%|█████          | 589/1755 [02:40<06:24,  3.04folder/s]
#
# Processing train_ds:  34%|█████          | 590/1755 [02:40<05:53,  3.30folder/s]
#
# Processing train_ds:  34%|█████          | 591/1755 [02:40<05:19,  3.64folder/s]
#
# Processing train_ds:  34%|█████          | 592/1755 [02:41<06:32,  2.97folder/s]
#
# Processing train_ds:  34%|█████          | 593/1755 [02:41<05:39,  3.42folder/s]
#
# Processing train_ds:  34%|█████          | 594/1755 [02:41<04:45,  4.07folder/s]
#
# Processing train_ds:  34%|█████          | 595/1755 [02:41<05:38,  3.43folder/s]
#
# Processing train_ds:  34%|█████          | 596/1755 [02:41<04:56,  3.91folder/s]
#
# Processing train_ds:  34%|█████          | 597/1755 [02:42<05:07,  3.77folder/s]
#
# Processing train_ds:  34%|█████          | 598/1755 [02:42<04:42,  4.09folder/s]
#
# Processing train_ds:  36%|█████▍         | 636/1755 [02:51<04:38,  4.02folder/s]
#
# Processing train_ds:  36%|█████▍         | 637/1755 [02:51<03:53,  4.80folder/s]
#
# Processing train_ds:  36%|█████▍         | 638/1755 [02:52<05:27,  3.41folder/s]
#
# Processing train_ds:  36%|█████▍         | 639/1755 [02:52<04:41,  3.96folder/s]
#
# Processing train_ds:  36%|█████▍         | 640/1755 [02:52<04:53,  3.79folder/s]
#
# Processing train_ds:  37%|█████▍         | 642/1755 [02:53<04:16,  4.33folder/s]
#
# Processing train_ds:  37%|█████▍         | 643/1755 [02:53<05:06,  3.63folder/s]
#
# Processing train_ds:  37%|█████▌         | 644/1755 [02:53<05:43,  3.24folder/s]
#
# Processing train_ds:  37%|█████▌         | 645/1755 [02:54<05:03,  3.65folder/s]
#
# Processing train_ds:  37%|█████▌         | 646/1755 [02:54<06:20,  2.92folder/s]
#
# Processing train_ds:  37%|█████▌         | 647/1755 [02:54<05:49,  3.17folder/s]
# Processing train_ds:  37%|█████▌         | 648/1755 [02:55<05:13,  3.53folder/s]
#
# Processing train_ds:  37%|█████▌         | 649/1755 [02:55<04:33,  4.04folder/s]
#
# Processing train_ds:  37%|█████▌         | 650/1755 [02:55<04:52,  3.78folder/s]
#
# Processing train_ds:  37%|█████▌         | 651/1755 [02:55<05:41,  3.23folder/s]
#
# Processing train_ds:  37%|█████▌         | 653/1755 [02:56<05:11,  3.54folder/s]
#
# Processing train_ds:  37%|█████▌         | 655/1755 [02:56<04:18,  4.26folder/s]
#
# Processing train_ds:  37%|█████▌         | 656/1755 [02:56<03:54,  4.68folder/s]
#
# Processing train_ds:  37%|█████▌         | 657/1755 [02:57<03:53,  4.71folder/s]
#
# Processing train_ds:  38%|█████▋         | 659/1755 [02:57<03:15,  5.61folder/s]
#
# Processing train_ds:  38%|█████▋         | 660/1755 [02:57<03:24,  5.36folder/s]
#
# Processing train_ds:  38%|█████▋         | 661/1755 [02:58<04:46,  3.81folder/s]
#
# Processing train_ds:  38%|█████▋         | 662/1755 [02:58<04:21,  4.18folder/s]
#
# Processing train_ds:  38%|█████▋         | 663/1755 [02:58<05:06,  3.56folder/s]
#
# Processing train_ds:  38%|█████▋         | 664/1755 [02:58<04:12,  4.32folder/s]
#
# Processing train_ds:  38%|█████▋         | 665/1755 [02:59<05:01,  3.61folder/s]
#
# Processing train_ds:  38%|█████▋         | 666/1755 [02:59<04:20,  4.18folder/s]
#
# Processing train_ds:  38%|█████▋         | 667/1755 [02:59<05:06,  3.55folder/s]
#
# Processing train_ds:  38%|█████▋         | 668/1755 [03:00<06:09,  2.94folder/s]
#
# Processing train_ds:  38%|█████▋         | 669/1755 [03:00<04:56,  3.66folder/s]
#
# Processing train_ds:  38%|█████▋         | 670/1755 [03:00<05:20,  3.38folder/s]
#
# Processing train_ds:  38%|█████▋         | 671/1755 [03:00<04:51,  3.72folder/s]
#
# Processing train_ds:  38%|█████▋         | 672/1755 [03:00<04:10,  4.32folder/s]
#
# Processing train_ds:  38%|█████▊         | 673/1755 [03:01<05:38,  3.19folder/s]
#
# Processing train_ds:  38%|█████▊         | 674/1755 [03:01<04:40,  3.85folder/s]
#
# Processing train_ds:  38%|█████▊         | 675/1755 [03:01<04:27,  4.04folder/s]
#
# Processing train_ds:  39%|█████▊         | 676/1755 [03:02<04:02,  4.45folder/s]
#
# Processing train_ds:  39%|█████▊         | 677/1755 [03:02<03:48,  4.71folder/s]
#
# ...
#
# Processing val_ds:  14%|██▉                  | 7/51 [00:21<02:35,  3.54s/folder]
#
# Processing val_ds:  16%|███▎                 | 8/51 [00:22<01:57,  2.73s/folder]
#
# Processing val_ds:  18%|███▋                 | 9/51 [00:23<01:32,  2.19s/folder]
#
# Processing val_ds:  20%|███▉                | 10/51 [00:27<01:49,  2.66s/folder]
#
# Processing val_ds:  22%|████▎               | 11/51 [00:31<02:06,  3.15s/folder]
#
# Processing val_ds:  24%|████▋               | 12/51 [00:34<02:02,  3.13s/folder]
#
# Processing val_ds:  25%|█████               | 13/51 [00:37<01:50,  2.90s/folder]
#
# Processing val_ds:  27%|█████▍              | 14/51 [00:39<01:44,  2.82s/folder]
#
# Processing val_ds:  29%|█████▉              | 15/51 [00:42<01:41,  2.81s/folder]
#
# Processing val_ds:  31%|██████▎             | 16/51 [00:46<01:55,  3.30s/folder]
#
# Processing val_ds:  33%|██████▋             | 17/51 [00:48<01:37,  2.87s/folder]
#
# Processing val_ds:  35%|███████             | 18/51 [00:52<01:42,  3.10s/folder]
#
# Processing val_ds:  37%|███████▍            | 19/51 [00:57<01:58,  3.70s/folder]
#
# Processing val_ds:  39%|███████▊            | 20/51 [00:58<01:32,  2.98s/folder]
#
# Processing val_ds:  41%|████████▏           | 21/51 [01:03<01:48,  3.60s/folder]
#
# Processing val_ds:  43%|████████▋           | 22/51 [01:05<01:29,  3.09s/folder]
#
# Processing val_ds:  45%|█████████           | 23/51 [01:07<01:13,  2.61s/folder]
#
# Processing val_ds:  47%|█████████▍          | 24/51 [01:08<01:00,  2.23s/folder]
#
# Processing val_ds:  49%|█████████▊          | 25/51 [01:13<01:18,  3.03s/folder]
#
# Processing val_ds:  51%|██████████▏         | 26/51 [01:18<01:29,  3.57s/folder]
#
# Processing val_ds:  53%|██████████▌         | 27/51 [01:19<01:11,  2.98s/folder]
#
# Processing val_ds:  55%|██████████▉         | 28/51 [01:21<01:01,  2.67s/folder]
#
# Processing val_ds:  57%|███████████▎        | 29/51 [01:23<00:51,  2.34s/folder]
#
# Processing val_ds:  59%|███████████▊        | 30/51 [01:26<00:52,  2.49s/folder]
#
# Processing val_ds:  61%|████████████▏       | 31/51 [01:29<00:54,  2.72s/folder]
#
# Processing val_ds:  63%|████████████▌       | 32/51 [01:32<00:54,  2.87s/folder]
#
# Processing val_ds:  65%|████████████▉       | 33/51 [01:36<00:53,  3.00s/folder]
#
# Processing val_ds:  67%|█████████████▎      | 34/51 [01:40<00:59,  3.49s/folder]
#
# Processing val_ds:  69%|█████████████▋      | 35/51 [01:43<00:51,  3.24s/folder]
#
# Processing val_ds:  71%|██████████████      | 36/51 [01:44<00:38,  2.57s/folder]
#
# Processing val_ds:  73%|██████████████▌     | 37/51 [01:48<00:44,  3.15s/folder]
#
# Processing val_ds:  75%|██████████████▉     | 38/51 [01:50<00:35,  2.77s/folder]
#
# Processing val_ds:  76%|███████████████▎    | 39/51 [01:54<00:36,  3.08s/folder]
#
# Processing val_ds:  78%|███████████████▋    | 40/51 [01:57<00:34,  3.11s/folder]
#
# Processing val_ds:  80%|████████████████    | 41/51 [02:01<00:31,  3.17s/folder]
#
# Processing val_ds:  82%|████████████████▍   | 42/51 [02:02<00:24,  2.76s/folder]
#
# Processing val_ds:  84%|████████████████▊   | 43/51 [02:07<00:25,  3.22s/folder]
#
# Processing val_ds:  86%|█████████████████▎  | 44/51 [02:08<00:18,  2.58s/folder]
#
# Processing val_ds:  88%|█████████████████▋  | 45/51 [02:09<00:13,  2.25s/folder]
#
# Processing val_ds:  90%|██████████████████  | 46/51 [02:11<00:11,  2.25s/folder]
#
# Processing val_ds:  92%|██████████████████▍ | 47/51 [02:13<00:08,  2.11s/folder]
#
# Processing val_ds:  94%|██████████████████▊ | 48/51 [02:16<00:07,  2.37s/folder]
#
# Processing val_ds:  96%|███████████████████▏| 49/51 [02:18<00:04,  2.24s/folder]
#
# Processing val_ds:  98%|███████████████████▌| 50/51 [02:19<00:01,  1.92s/folder]
#
# Processing val_ds: 100%|████████████████████| 51/51 [02:22<00:00,  2.79s/folder]
#
#
# Processing test_ds:   0%|                           | 0/148 [00:00<?, ?folder/s]
# Processing test_ds:   1%|▏                  | 1/148 [00:00<02:11,  1.12folder/s]
#
# Processing test_ds:   1%|▎                  | 2/148 [00:01<02:10,  1.12folder/s]
#
# Processing test_ds:   2%|▍                  | 3/148 [00:02<02:28,  1.02s/folder]
#
# Processing test_ds:   3%|▌                  | 4/148 [00:04<02:30,  1.04s/folder]
#
# Processing test_ds:   3%|▋                  | 5/148 [00:05<02:25,  1.02s/folder]
#
# Processing test_ds:   4%|▊                  | 6/148 [00:06<02:24,  1.02s/folder]
#
# Processing test_ds:   5%|▉                  | 7/148 [00:07<02:26,  1.04s/folder]
#
# Processing test_ds:   5%|█                  | 8/148 [00:08<02:28,  1.06s/folder]
#
# Processing test_ds:   6%|█▏                 | 9/148 [00:09<02:18,  1.00folder/s]
#
# Processing test_ds:   7%|█▏                | 10/148 [00:10<02:23,  1.04s/folder]
#
# Processing test_ds:   7%|█▎                | 11/148 [00:11<02:18,  1.01s/folder]
#
# Processing test_ds:   8%|█▍                | 12/148 [00:12<02:18,  1.02s/folder]
#
# Processing test_ds:   9%|█▌                | 13/148 [00:13<02:35,  1.15s/folder]
#
# Processing test_ds:   9%|█▋                | 14/148 [00:14<02:27,  1.10s/folder]
#
# Processing test_ds:  10%|█▊                | 15/148 [00:15<02:20,  1.06s/folder]
#
# Processing test_ds:  11%|█▉                | 16/148 [00:16<02:22,  1.08s/folder]
#
# Processing test_ds:  11%|██                | 17/148 [00:17<02:20,  1.07s/folder]
#
# Processing test_ds:  12%|██▏               | 18/148 [00:18<02:17,  1.06s/folder]
#
# Processing test_ds:  13%|██▎               | 19/148 [00:19<02:14,  1.04s/folder]
#
# Processing test_ds:  14%|██▍               | 20/148 [00:20<02:16,  1.06s/folder]
#
# Processing test_ds:  14%|██▌               | 21/148 [00:21<02:10,  1.03s/folder]
#
# Processing test_ds:  15%|██▋               | 22/148 [00:22<02:03,  1.02folder/s]
#
# Processing test_ds:  16%|██▊               | 23/148 [00:23<02:05,  1.01s/folder]
#
# Processing test_ds:  16%|██▉               | 24/148 [00:25<02:11,  1.06s/folder]
#
# Processing test_ds:  17%|███               | 25/148 [00:25<02:07,  1.03s/folder]
#
# Processing test_ds:  18%|███▏              | 26/148 [00:26<02:03,  1.02s/folder]
#
# Processing test_ds:  18%|███▎              | 27/148 [00:27<02:03,  1.02s/folder]
#
# Processing test_ds:  19%|███▍              | 28/148 [00:28<01:57,  1.02folder/s]
#
# Processing test_ds:  20%|███▌              | 29/148 [00:29<02:00,  1.01s/folder]
#
# Processing test_ds:  20%|███▋              | 30/148 [00:30<01:53,  1.04folder/s]
#
# Processing test_ds:  21%|███▊              | 31/148 [00:31<01:48,  1.08folder/s]
#
# Processing test_ds:  22%|███▉              | 32/148 [00:32<02:01,  1.05s/folder]
#
# Processing test_ds:  22%|████              | 33/148 [00:34<02:00,  1.05s/folder]
#
# Processing test_ds:  23%|████▏             | 34/148 [00:34<01:56,  1.03s/folder]
#
# Processing test_ds:  24%|████▎             | 35/148 [00:35<01:52,  1.00folder/s]
#
# Processing test_ds:  24%|████▍             | 36/148 [00:36<01:50,  1.01folder/s]
#
# Processing test_ds:  25%|████▌             | 37/148 [00:37<01:52,  1.02s/folder]
#
# Processing test_ds:  26%|████▌             | 38/148 [00:39<01:54,  1.04s/folder]
#
# Processing test_ds:  26%|████▋             | 39/148 [00:40<01:51,  1.02s/folder]
#
# Processing test_ds:  27%|████▊             | 40/148 [00:40<01:48,  1.00s/folder]
#
# Processing test_ds:  28%|████▉             | 41/148 [00:41<01:43,  1.03folder/s]
#
# Processing test_ds:  28%|█████             | 42/148 [00:45<03:16,  1.85s/folder]
#
# Processing test_ds:  29%|█████▏            | 43/148 [00:46<02:49,  1.62s/folder]
#
# Processing test_ds:  30%|█████▎            | 44/148 [00:47<02:28,  1.43s/folder]
#
# Processing test_ds:  30%|█████▍            | 45/148 [00:48<02:13,  1.30s/folder]
#
# Processing test_ds:  31%|█████▌            | 46/148 [00:49<01:58,  1.16s/folder]
#
# Processing test_ds:  32%|█████▋            | 47/148 [00:50<01:54,  1.14s/folder]
#
# Processing test_ds:  32%|█████▊            | 48/148 [00:51<01:55,  1.15s/folder]
#
# Processing test_ds:  33%|█████▉            | 49/148 [00:53<01:52,  1.14s/folder]
#
# Processing test_ds:  34%|██████            | 50/148 [00:54<01:52,  1.15s/folder]
#
# Processing test_ds:  34%|██████▏           | 51/148 [00:55<01:44,  1.07s/folder]
#
# Processing test_ds:  35%|██████▎           | 52/148 [00:56<01:46,  1.11s/folder]
#
# Processing test_ds:  36%|██████▍           | 53/148 [00:57<01:43,  1.09s/folder]
#
# Processing test_ds:  36%|██████▌           | 54/148 [00:58<01:39,  1.06s/folder]
#
# Processing test_ds:  37%|██████▋           | 55/148 [00:59<01:37,  1.05s/folder]
#
# Processing test_ds:  38%|██████▊           | 56/148 [01:00<01:37,  1.06s/folder]
#
# Processing test_ds:  39%|██████▉           | 57/148 [01:01<01:35,  1.05s/folder]
#
# Processing test_ds:  39%|███████           | 58/148 [01:02<01:31,  1.02s/folder]
#
# Processing test_ds:  40%|███████▏          | 59/148 [01:03<01:33,  1.05s/folder]
#
# Processing test_ds:  41%|███████▎          | 60/148 [01:04<01:27,  1.01folder/s]
#
# Processing test_ds:  41%|███████▍          | 61/148 [01:05<01:31,  1.05s/folder]
#
# Processing test_ds:  42%|███████▌          | 62/148 [01:06<01:25,  1.01folder/s]
#
# Processing test_ds:  43%|███████▋          | 63/148 [01:07<01:27,  1.03s/folder]
#
# Processing test_ds:  43%|███████▊          | 64/148 [01:08<01:21,  1.03folder/s]
#
# Processing test_ds:  44%|███████▉          | 65/148 [01:09<01:22,  1.00folder/s]
#
# Processing test_ds:  45%|████████          | 66/148 [01:10<01:23,  1.01s/folder]
#
# Processing test_ds:  45%|████████▏         | 67/148 [01:11<01:21,  1.01s/folder]
#
# Processing test_ds:  46%|████████▎         | 68/148 [01:12<01:18,  1.02folder/s]
#
# Processing test_ds:  47%|████████▍         | 69/148 [01:13<01:20,  1.02s/folder]
#
# Processing test_ds:  47%|████████▌         | 70/148 [01:14<01:18,  1.01s/folder]
#
# Processing test_ds:  48%|████████▋         | 71/148 [01:15<01:15,  1.02folder/s]
#
# Processing test_ds:  49%|████████▊         | 72/148 [01:16<01:16,  1.01s/folder]
#
# Processing test_ds:  49%|████████▉         | 73/148 [01:17<01:23,  1.11s/folder]
#
# Processing test_ds:  50%|█████████         | 74/148 [01:18<01:20,  1.08s/folder]
#
# Processing test_ds:  51%|█████████         | 75/148 [01:19<01:16,  1.04s/folder]
#
# Processing test_ds:  51%|█████████▏        | 76/148 [01:20<01:14,  1.04s/folder]
#
# Processing test_ds:  52%|█████████▎        | 77/148 [01:21<01:14,  1.05s/folder]
#
# Processing test_ds:  53%|█████████▍        | 78/148 [01:23<01:14,  1.06s/folder]
#
# Processing test_ds:  53%|█████████▌        | 79/148 [01:24<01:11,  1.03s/folder]
#
# Processing test_ds:  54%|█████████▋        | 80/148 [01:25<01:15,  1.10s/folder]
#
# Processing test_ds:  55%|█████████▊        | 81/148 [01:26<01:13,  1.09s/folder]
#
# Processing test_ds:  55%|█████████▉        | 82/148 [01:27<01:10,  1.07s/folder]
#
# Processing test_ds:  56%|██████████        | 83/148 [01:28<01:07,  1.03s/folder]
#
# Processing test_ds:  57%|██████████▏       | 84/148 [01:29<01:03,  1.01folder/s]
#
# Processing test_ds:  57%|██████████▎       | 85/148 [01:30<01:00,  1.04folder/s]
#
# Processing test_ds:  58%|██████████▍       | 86/148 [01:31<01:07,  1.09s/folder]
#
# Processing test_ds:  59%|██████████▌       | 87/148 [01:32<01:08,  1.12s/folder]
#
# Processing test_ds:  59%|██████████▋       | 88/148 [01:33<01:05,  1.09s/folder]
#
# Processing test_ds:  60%|██████████▊       | 89/148 [01:34<01:03,  1.08s/folder]
#
# Processing test_ds:  61%|██████████▉       | 90/148 [01:35<01:01,  1.07s/folder]
#
# Processing test_ds:  61%|███████████       | 91/148 [01:36<01:00,  1.07s/folder]
#
# Processing test_ds:  62%|███████████▏      | 92/148 [01:37<00:59,  1.07s/folder]
#
# Processing test_ds:  63%|███████████▎      | 93/148 [01:39<00:59,  1.09s/folder]
# Processing test_ds:  64%|███████████▍      | 94/148 [01:40<00:59,  1.09s/folder]
#
# Processing test_ds:  64%|███████████▌      | 95/148 [01:41<00:56,  1.06s/folder]
#
# Processing test_ds:  65%|███████████▋      | 96/148 [01:42<00:53,  1.03s/folder]
#
# Processing test_ds:  66%|███████████▊      | 97/148 [01:43<00:54,  1.07s/folder]
#
# Processing test_ds:  66%|███████████▉      | 98/148 [01:44<00:54,  1.09s/folder]
#
# Processing test_ds:  67%|████████████      | 99/148 [01:45<00:53,  1.09s/folder]
#
# Processing test_ds:  68%|███████████▍     | 100/148 [01:46<00:49,  1.03s/folder]
#
# Processing test_ds:  68%|███████████▌     | 101/148 [01:47<00:48,  1.02s/folder]
#
# Processing test_ds:  69%|███████████▋     | 102/148 [01:48<00:45,  1.01folder/s]
#
# Processing test_ds:  70%|███████████▊     | 103/148 [01:49<00:45,  1.01s/folder]
#
# Processing test_ds:  70%|███████████▉     | 104/148 [01:50<00:43,  1.02folder/s]
#
# Processing test_ds:  71%|████████████     | 105/148 [01:51<00:42,  1.02folder/s]
#
# Processing test_ds:  72%|████████████▏    | 106/148 [01:52<00:42,  1.00s/folder]
#
# Processing test_ds:  72%|████████████▎    | 107/148 [01:53<00:40,  1.01folder/s]
#
# Processing test_ds:  73%|████████████▍    | 108/148 [01:54<00:42,  1.06s/folder]
#
# Processing test_ds:  74%|████████████▌    | 109/148 [01:55<00:42,  1.09s/folder]
#
# Processing test_ds:  74%|████████████▋    | 110/148 [01:56<00:41,  1.10s/folder]
#
# Processing test_ds:  75%|████████████▊    | 111/148 [01:57<00:40,  1.08s/folder]
#
# Processing test_ds:  76%|████████████▊    | 112/148 [01:58<00:33,  1.08folder/s]
#
# Processing test_ds:  76%|████████████▉    | 113/148 [01:59<00:34,  1.02folder/s]
#
# Processing test_ds:  77%|█████████████    | 114/148 [02:00<00:33,  1.00folder/s]
#
# Processing test_ds:  78%|█████████████▏   | 115/148 [02:01<00:34,  1.04s/folder]
#
# Processing test_ds:  78%|█████████████▎   | 116/148 [02:02<00:32,  1.03s/folder]
#
# Processing test_ds:  79%|█████████████▍   | 117/148 [02:03<00:31,  1.01s/folder]
#
# Processing test_ds:  80%|█████████████▌   | 118/148 [02:04<00:30,  1.03s/folder]
#
# Processing test_ds:  80%|█████████████▋   | 119/148 [02:05<00:29,  1.02s/folder]
#
# Processing test_ds:  81%|█████████████▊   | 120/148 [02:06<00:28,  1.02s/folder]
#
# Processing test_ds:  82%|█████████████▉   | 121/148 [02:07<00:27,  1.01s/folder]
#
# Processing test_ds:  82%|██████████████   | 122/148 [02:08<00:26,  1.02s/folder]
#
# Processing test_ds:  83%|██████████████▏  | 123/148 [02:10<00:27,  1.11s/folder]
#
# Processing test_ds:  84%|██████████████▏  | 124/148 [02:11<00:26,  1.10s/folder]
#
# Processing test_ds:  84%|██████████████▎  | 125/148 [02:12<00:25,  1.10s/folder]
#
# Processing test_ds:  85%|██████████████▍  | 126/148 [02:13<00:23,  1.07s/folder]
#
# Processing test_ds:  86%|██████████████▌  | 127/148 [02:14<00:21,  1.02s/folder]
#
# Processing test_ds:  86%|██████████████▋  | 128/148 [02:15<00:19,  1.01folder/s]
#
# Processing test_ds:  87%|██████████████▊  | 129/148 [02:16<00:19,  1.04s/folder]
#
# Processing test_ds:  88%|██████████████▉  | 130/148 [02:17<00:18,  1.05s/folder]
#
# Processing test_ds:  89%|███████████████  | 131/148 [02:18<00:17,  1.05s/folder]
#
# Processing test_ds:  89%|███████████████▏ | 132/148 [02:19<00:17,  1.08s/folder]
#
# Processing test_ds:  90%|███████████████▎ | 133/148 [02:20<00:16,  1.09s/folder]
#
# Processing test_ds:  91%|███████████████▍ | 134/148 [02:21<00:15,  1.08s/folder]
#
# Processing test_ds:  91%|███████████████▌ | 135/148 [02:22<00:14,  1.10s/folder]
#
# Processing test_ds:  92%|███████████████▌ | 136/148 [02:23<00:12,  1.08s/folder]
#
# Processing test_ds:  93%|███████████████▋ | 137/148 [02:24<00:11,  1.03s/folder]
#
# Processing test_ds:  93%|███████████████▊ | 138/148 [02:25<00:10,  1.05s/folder]
#
# Processing test_ds:  94%|███████████████▉ | 139/148 [02:26<00:09,  1.03s/folder]
#
# Processing test_ds:  95%|████████████████ | 140/148 [02:28<00:08,  1.11s/folder]
#
# Processing test_ds:  95%|████████████████▏| 141/148 [02:29<00:07,  1.05s/folder]
#
# Processing test_ds:  96%|████████████████▎| 142/148 [02:30<00:06,  1.08s/folder]
#
# Processing test_ds:  97%|████████████████▍| 143/148 [02:31<00:05,  1.08s/folder]
#
# Processing test_ds:  97%|████████████████▌| 144/148 [02:32<00:04,  1.07s/folder]
#
# Processing test_ds:  98%|████████████████▋| 145/148 [02:33<00:03,  1.08s/folder]
#
# Processing test_ds:  99%|████████████████▊| 146/148 [02:34<00:02,  1.01s/folder]
#
# Processing test_ds:  99%|████████████████▉| 147/148 [02:35<00:01,  1.02s/folder]
#
# Processing test_ds: 100%|█████████████████| 148/148 [02:36<00:00,  1.06s/folder]
# Image loading completed!

# %%
import torch

# Check if CUDA (GPU acceleration) is available
cuda_available = torch.cuda.is_available()

if cuda_available:
    # Get the CUDA device count
    cuda_device_count = torch.cuda.device_count()
    print('CUDA is available with {cuda_device_count} CUDA device(s)!')
else:
    print('CUDA is not available. Running on CPU.')
# Out:
# CUDA is not available. Running on CPU.

# %%
def load_images_and_labels_from_directory(base_dir, target_size=(64, 64)):
    images = []
    labels = []
    for label in os.listdir(base_dir):
        label_dir = os.path.join(base_dir, label)
        if os.path.isdir(label_dir):
            for filename in os.listdir(label_dir):
                if filename.endswith('.png') or filename.endswith('.jpg'):
                    img_path = os.path.join(label_dir, filename)
                    img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
                    if img is not None:
                        resized_img = cv2.resize(img, target_size)
                        images.append(resized_img)
                        labels.append(label)
    return np.array(images), np.array(labels)

# %%
train_images, train_labels = load_images_and_labels_from_directory('/Users/apoorvagayatrik/PerspectAIProj/processed_images/train_ds')
val_images, val_labels = load_images_and_labels_from_directory('/Users/apoorvagayatrik/PerspectAIProj/processed_images/val_ds')
test_images, test_labels = load_images_and_labels_from_directory('/Users/apoorvagayatrik/PerspectAIProj/processed_images/test_ds')

# %%
def compute_covmatrix(images):
    num_images = len(images)
    flattened_images = np.array([img.flatten() for img in images])
    mean_image = np.mean(flattened_images, axis=0)
    cov_matrix = np.cov(flattened_images, rowvar=False)
    return cov_matrix



train_cov_matrix = compute_covmatrix(train_images)
val_cov_matrix = compute_covmatrix(val_images)
test_cov_matrix = compute_covmatrix(test_images)

# %%
def extract_principal_components(cov_matrix,num_components):
    eig_vals,eig_vecs=np.linalg.eigh(cov_matrix)

    sorted_indices=np.argsort(eig_vals)[::-1]
    sorted_eig_vals=eig_vals[sorted_indices]
    sorted_eig_vecs=eig_vecs[:,sorted_indices]
  

    principal_components=sorted_eig_vecs[:,:num_components]

    return principal_components


num_components = 50

train_principal_components = extract_principal_components(train_cov_matrix, num_components)
val_principal_components = extract_principal_components(val_cov_matrix, num_components)
test_principal_components = extract_principal_components(test_cov_matrix, num_components)

# %%
def project_images(images,principal_components):
    num_images = len(images)
    flattened_images = images.reshape(num_images, -1)  # Flatten each image into a vector
    projected_images = np.dot(flattened_images, principal_components)

    return projected_images

train_projected = project_images(train_images, train_principal_components)

# %%
from sklearn.neighbors import KNeighborsClassifier

def train_classifier(projections,labels):
    knn=KNeighborsClassifier(n_neighbors=5)
    knn.fit(projections,labels)
    return knn


knn_classifier = train_classifier(train_projected, train_labels)

# %%
# !pip3 install scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.5.0-cp310-cp310-macosx_12_0_arm64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.19.5 in /Users/apoorvagayatrik/miniforge3/envs/tf_env/lib/python3.10/site-packages (from scikit-learn) (1.26.4)
# Collecting scipy>=1.6.0 (from scikit-learn)
#   Downloading scipy-1.13.1-cp310-cp310-macosx_12_0_arm64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 502.0 kB/s eta 0:00:00a 0:00:01
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.5.0-cp310-cp310-macosx_12_0_arm64.whl (11.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.0/11.0 MB 9.9 MB/s eta 0:00:00:00:010:01
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.8/301.8 kB 8.4 MB/s eta 0:00:00
# Downloading scipy-1.13.1-cp310-cp310-macosx_12_0_arm64.whl (30.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.3/30.3 MB 10.2 MB/s eta 0:00:0000:0100:01
# Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.4.2 scikit-learn-1.5.0 scipy-1.13.1 threadpoolctl-3.5.0

# %%
from sklearn.metrics import accuracy_score, classification_report


def evaluate_classifier(knn_classifier, test_images, test_labels, principal_components):
    num_images = len(test_images)
    flattened_images = np.array([img.flatten() for img in test_images])
    projected_images = np.dot(flattened_images, principal_components)
    predictions = knn_classifier.predict(projected_images)
    accuracy = accuracy_score(test_labels, predictions)
    report = classification_report(test_labels, predictions)
    return accuracy, report

# Evaluate classifier on validation and test datasets
val_accuracy, val_report = evaluate_classifier(knn_classifier, val_images, val_labels, val_principal_components)
test_accuracy, test_report = evaluate_classifier(knn_classifier, test_images, test_labels, test_principal_components)
print(f"Validation Accuracy: {val_accuracy}")
print(f"Validation Report:\n{val_report}")
print(f"Test Accuracy: {test_accuracy}")
print(f"Test